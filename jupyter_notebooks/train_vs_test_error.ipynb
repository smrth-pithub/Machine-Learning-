# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(42)

X = np.linspace(0, 10, 30)
y = 2 * X + np.random.randn(30) * 2

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
def evaluate_model(deg):
    model = np.polyfit(X_train, y_train, deg=deg)

    y_train_pred = np.polyval(model, X_train)
    y_test_pred = np.polyval(model, X_test)

    train_error = mean_squared_error(y_train, y_train_pred)
    test_error = mean_squared_error(y_test, y_test_pred)

    return train_error, test_error

# %%
degrees = [1, 2, 4, 6, 15]

for d in degrees:
    train_err, test_err = evaluate_model(d)
    print(f"Degree {d}: Train Error = {train_err:.2f}, Test Error = {test_err:.2f}")
# Out:
# Degree 1: Train Error = 3.36, Test Error = 1.41
# Degree 2: Train Error = 2.97, Test Error = 1.60
# Degree 4: Train Error = 2.33, Test Error = 2.98
# Degree 6: Train Error = 1.62, Test Error = 5.14
# Degree 15: Train Error = 0.99, Test Error = 20523.81

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Hp\Documents\ML\venv\Scripts\python.exe

# %%
import numpy
import pandas
import sklearn
import matplotlib.pyplot

print("everything is working fine")
# Out:
# everything is working fine
